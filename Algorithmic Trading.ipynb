# %% [markdown]
# # Algo Trading

# %% [markdown]
# ## Imports/Downloads

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',100)

# %%
ticker = ["SPY", "KO", "AAPL", "MSFT"]

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2023-11-30")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
stocks.head()
# Out:
#            Adj Close                                      Close             \
#                 AAPL         KO       MSFT        SPY      AAPL         KO
# Date
# 2010-01-04  6.478998  18.498018  23.474920  87.483185  7.643214  28.520000
# 2010-01-05  6.490201  18.274254  23.482500  87.714775  7.656429  28.174999
# 2010-01-06  6.386965  18.267765  23.338396  87.776535  7.534643  28.165001
# 2010-01-07  6.375156  18.222366  23.095688  88.147049  7.520714  28.094999
# 2010-01-08  6.417541  17.885090  23.254959  88.440399  7.570714  27.575001
#
#                                        High                                    \
#                  MSFT         SPY      AAPL         KO       MSFT         SPY
# Date
# 2010-01-04  30.950001  113.330002  7.660714  28.610001  31.100000  113.389999
# 2010-01-05  30.959999  113.629997  7.699643  28.495001  31.100000  113.680000
# 2010-01-06  30.770000  113.709999  7.686786  28.219999  31.080000  113.989998
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                                          Close  \
#                   AAPL         KO        MSFT         SPY        AAPL
# Date
# 2023-11-22  191.309998  57.958496  377.850006  455.019989  191.309998
# 2023-11-24  189.970001  58.107315  377.429993  455.299988  189.970001
# 2023-11-27  189.789993  57.998184  378.609985  454.480011  189.789993
# 2023-11-28  190.399994  58.117237  382.700012  454.929993  190.399994
# 2023-11-29  189.369995  57.770000  378.850006  454.609985  189.369995
#
#                                                      High             \
#                    KO        MSFT         SPY        AAPL         KO
# Date
# 2023-11-22  58.419998  377.850006  455.019989  192.929993  58.540001
# 2023-11-24  58.570000  377.429993  455.299988  190.899994  58.750000
# 2023-11-27  58.459999  378.609985  454.480011  190.669998  58.689999
# 2023-11-28  58.580002  382.700012  454.929993  191.080002  58.830002
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3501 entries, 2010-01-04 to 2023-11-29
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3501 non-null   float64
#  1   (Adj Close, KO)    3501 non-null   float64
#  2   (Adj Close, MSFT)  3501 non-null   float64
#  3   (Adj Close, SPY)   3501 non-null   float64
#  4   (Close, AAPL)      3501 non-null   float64
#  5   (Close, KO)        3501 non-null   float64
#  6   (Close, MSFT)      3501 non-null   float64
#  7   (Close, SPY)       3501 non-null   float64
#  8   (High, AAPL)       3501 non-null   float64
#  9   (High, KO)         3501 non-null   float64
#  10  (High, MSFT)       3501 non-null   float64
#  11  (High, SPY)        3501 non-null   float64
#  12  (Low, AAPL)        3501 non-null   float64
#  13  (Low, KO)          3501 non-null   float64
#  14  (Low, MSFT)        3501 non-null   float64
# ...

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                MSFT
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.478997707366943  18.498018264770508   23.47492027282715
# 3     2010-01-05   6.490200996398926  18.274253845214844  23.482500076293945
# 4     2010-01-06   6.386964797973633  18.267765045166016  23.338396072387695
# ...          ...                 ...                 ...                 ...
# 3498  2023-11-22  191.30999755859375      57.95849609375   377.8500061035156
# 3499  2023-11-24  189.97000122070312   58.10731506347656  377.42999267578125
# 3500  2023-11-27   189.7899932861328   57.99818420410156   378.6099853515625
# 3501  2023-11-28  190.39999389648438   58.11723709106445  382.70001220703125
# 3502  2023-11-29   189.3699951171875   57.77000045776367   378.8500061035156
#
# ...

# %%
stocks = pd.read_csv("stocks.csv", header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                                     \
#      Unnamed: 0_level_1        AAPL         KO        MSFT         SPY
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.478998  18.498018   23.474920   87.483185
# 2            2010-01-05    6.490201  18.274254   23.482500   87.714775
# 3            2010-01-06    6.386965  18.267765   23.338396   87.776535
# 4            2010-01-07    6.375156  18.222366   23.095688   88.147049
# ...                 ...         ...        ...         ...         ...
# 3497         2023-11-22  191.309998  57.958496  377.850006  455.019989
# 3498         2023-11-24  189.970001  58.107315  377.429993  455.299988
# 3499         2023-11-27  189.789993  57.998184  378.609985  454.480011
# 3500         2023-11-28  190.399994  58.117237  382.700012  454.929993
# 3501         2023-11-29  189.369995  57.770000  378.850006  454.609985
#
# ...

# %%
stocks = pd.read_csv("stocks.csv", header=[0,1], index_col=[0])
stocks.head()
# Out:
#            Adj Close                                      Close             \
#                 AAPL         KO       MSFT        SPY      AAPL         KO
# Date
# 2010-01-04  6.478998  18.498018  23.474920  87.483185  7.643214  28.520000
# 2010-01-05  6.490201  18.274254  23.482500  87.714775  7.656429  28.174999
# 2010-01-06  6.386965  18.267765  23.338396  87.776535  7.534643  28.165001
# 2010-01-07  6.375156  18.222366  23.095688  88.147049  7.520714  28.094999
# 2010-01-08  6.417541  17.885090  23.254959  88.440399  7.570714  27.575001
#
#                                        High                                    \
#                  MSFT         SPY      AAPL         KO       MSFT         SPY
# Date
# 2010-01-04  30.950001  113.330002  7.660714  28.610001  31.100000  113.389999
# 2010-01-05  30.959999  113.629997  7.699643  28.495001  31.100000  113.680000
# 2010-01-06  30.770000  113.709999  7.686786  28.219999  31.080000  113.989998
# ...

# %%
stocks = pd.read_csv("stocks.csv", header=[0,1], index_col=[0], parse_dates=[0])
stocks.head()
# Out:
#            Adj Close                                      Close             \
#                 AAPL         KO       MSFT        SPY      AAPL         KO
# Date
# 2010-01-04  6.478998  18.498018  23.474920  87.483185  7.643214  28.520000
# 2010-01-05  6.490201  18.274254  23.482500  87.714775  7.656429  28.174999
# 2010-01-06  6.386965  18.267765  23.338396  87.776535  7.534643  28.165001
# 2010-01-07  6.375156  18.222366  23.095688  88.147049  7.520714  28.094999
# 2010-01-08  6.417541  17.885090  23.254959  88.440399  7.570714  27.575001
#
#                                        High                                    \
#                  MSFT         SPY      AAPL         KO       MSFT         SPY
# Date
# 2010-01-04  30.950001  113.330002  7.660714  28.610001  31.100000  113.389999
# 2010-01-05  30.959999  113.629997  7.699643  28.495001  31.100000  113.680000
# 2010-01-06  30.770000  113.709999  7.686786  28.219999  31.080000  113.989998
# ...

# %% [markdown]
# ### Convert to and from Multi-Index

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close', 'MSFT'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High', 'MSFT'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low', 'MSFT'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open', 'MSFT'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume', 'MSFT'),
#             (   'Volume',  'SPY')],
#            )

# %%
# convert multi index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#         ('Adj Close', 'SPY'),     ('Close', 'AAPL'),       ('Close', 'KO'),
#            ('Close', 'MSFT'),      ('Close', 'SPY'),      ('High', 'AAPL'),
#               ('High', 'KO'),      ('High', 'MSFT'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#               ('Low', 'SPY'),      ('Open', 'AAPL'),        ('Open', 'KO'),
#             ('Open', 'MSFT'),       ('Open', 'SPY'),    ('Volume', 'AAPL'),
#             ('Volume', 'KO'),    ('Volume', 'MSFT'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, MSFT)  \
# Date
# 2010-01-04           6.478998        18.498018          23.474920
# 2010-01-05           6.490201        18.274254          23.482500
# 2010-01-06           6.386965        18.267765          23.338396
# 2010-01-07           6.375156        18.222366          23.095688
# 2010-01-08           6.417541        17.885090          23.254959
# ...                       ...              ...                ...
# 2023-11-22         191.309998        57.958496         377.850006
# 2023-11-24         189.970001        58.107315         377.429993
# 2023-11-27         189.789993        57.998184         378.609985
# 2023-11-28         190.399994        58.117237         382.700012
# 2023-11-29         189.369995        57.770000         378.850006
#
#             (Adj Close, SPY)  (Close, AAPL)  (Close, KO)  (Close, MSFT)  \
# Date
# 2010-01-04         87.483185       7.643214    28.520000      30.950001
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks
# Out:
#              Adj Close                                          Close  \
#                   AAPL         KO        MSFT         SPY        AAPL
# Date
# 2010-01-04    6.478998  18.498018   23.474920   87.483185    7.643214
# 2010-01-05    6.490201  18.274254   23.482500   87.714775    7.656429
# 2010-01-06    6.386965  18.267765   23.338396   87.776535    7.534643
# 2010-01-07    6.375156  18.222366   23.095688   88.147049    7.520714
# 2010-01-08    6.417541  17.885090   23.254959   88.440399    7.570714
# ...                ...        ...         ...         ...         ...
# 2023-11-22  191.309998  57.958496  377.850006  455.019989  191.309998
# 2023-11-24  189.970001  58.107315  377.429993  455.299988  189.970001
# 2023-11-27  189.789993  57.998184  378.609985  454.480011  189.789993
# 2023-11-28  190.399994  58.117237  382.700012  454.929993  190.399994
# 2023-11-29  189.369995  57.770000  378.850006  454.609985  189.369995
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close', 'MSFT'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High', 'MSFT'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low', 'MSFT'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open', 'MSFT'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume', 'MSFT'),
#             (   'Volume',  'SPY')],
#            )

# %% [markdown]
# ## Exploring Stocks

# %%
stocks.describe()
# Out:
#          Adj Close                                               Close  \
#               AAPL           KO         MSFT          SPY         AAPL
# count  3501.000000  3501.000000  3501.000000  3501.000000  3501.000000
# mean     57.103503    37.144117   108.406149   230.484565    59.121408
# std      55.012309    12.249083   100.917548   112.427158    54.624564
# min       5.814177    16.373819    17.613333    79.593346     6.858929
# 25%      17.015957    28.082361    27.326889   136.326721    19.502857
# 50%      28.992744    34.758987    56.883068   200.020828    32.174999
# 75%      82.227280    46.266865   181.912781   306.451660    83.974998
# max     195.926956    62.817848   382.700012   464.923401   196.449997
#
#                                                      High               \
#                 KO         MSFT          SPY         AAPL           KO
# count  3501.000000  3501.000000  3501.000000  3501.000000  3501.000000
# ...

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL         KO        MSFT         SPY
# Date
# 2010-01-04    7.643214  28.520000   30.950001  113.330002
# 2010-01-05    7.656429  28.174999   30.959999  113.629997
# 2010-01-06    7.534643  28.165001   30.770000  113.709999
# 2010-01-07    7.520714  28.094999   30.450001  114.190002
# 2010-01-08    7.570714  27.575001   30.660000  114.570000
# ...                ...        ...         ...         ...
# 2023-11-22  191.309998  58.419998  377.850006  455.019989
# 2023-11-24  189.970001  58.570000  377.429993  455.299988
# 2023-11-27  189.789993  58.459999  378.609985  454.480011
# 2023-11-28  190.399994  58.580002  382.700012  454.929993
# 2023-11-29  189.369995  58.230000  378.850006  454.609985
#
# [3501 rows x 4 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# C:\Users\cjhun\AppData\Local\Temp\ipykernel_13328\715908909.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
# Normalize
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2023-11-22    2503.004520
# 2023-11-24    2485.472677
# 2023-11-27    2483.117543
# 2023-11-28    2491.098486
# 2023-11-29    2477.622497
# Name: AAPL, Length: 3501, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# MSFT     30.950001
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         MSFT         SPY
# Date
# 2010-01-04   100.000000  100.000000   100.000000  100.000000
# 2010-01-05   100.172893   98.790318   100.032305  100.264710
# 2010-01-06    98.579511   98.755261    99.418416  100.335302
# 2010-01-07    98.397266   98.509814    98.384491  100.758846
# 2010-01-08    99.051443   96.686537    99.063002  101.094148
# ...                 ...         ...          ...         ...
# 2023-11-22  2503.004520  204.838700  1220.840054  401.500028
# 2023-11-24  2485.472677  205.364652  1219.482983  401.747093
# 2023-11-27  2483.117543  204.978956  1223.295561  401.023563
# 2023-11-28  2491.098486  205.399723  1236.510510  401.420617
# 2023-11-29  2477.622497  204.172506  1224.071072  401.138249
#
# [3501 rows x 4 columns]

# %%
normal_close = close.div(close.iloc[0]).mul(100)

# %%
normal_close = close.div(close.iloc[0]).mul(100)

normal_close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ## Exploring AAPL stock

# %%
aapl = close.AAPL.copy().to_frame() # convert data to DataFrame

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-11-22  191.309998
# 2023-11-24  189.970001
# 2023-11-27  189.789993
# 2023-11-28  190.399994
# 2023-11-29  189.369995
#
# [3501 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2023-11-22  190.639999
# 2023-11-24  191.309998
# 2023-11-27  189.970001
# 2023-11-28  189.789993
# 2023-11-29  190.399994
#
# [3501 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2023-11-22  191.309998  190.639999
# 2023-11-24  189.970001  191.309998
# 2023-11-27  189.789993  189.970001
# 2023-11-28  190.399994  189.789993
# 2023-11-29  189.369995  190.399994
#
# [3501 rows x 2 columns]

# %%
# calculate the difference
aapl['Diff'] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2023-11-22  191.309998  190.639999  0.669998
# 2023-11-24  189.970001  191.309998 -1.339996
# 2023-11-27  189.789993  189.970001 -0.180008
# 2023-11-28  190.399994  189.789993  0.610001
# 2023-11-29  189.369995  190.399994 -1.029999
#
# [3501 rows x 3 columns]

# %%
aapl['% Change'] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2023-11-22  191.309998  190.639999  0.669998  0.351447
# 2023-11-24  189.970001  191.309998 -1.339996 -0.700432
# 2023-11-27  189.789993  189.970001 -0.180008 -0.094756
# 2023-11-28  190.399994  189.789993  0.610001  0.321408
# 2023-11-29  189.369995  190.399994 -1.029999 -0.540966
#
# [3501 rows x 4 columns]

# %%
# Using the diff method
aapl['Diff2'] = aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2023-11-22  191.309998  190.639999  0.669998  0.351447  0.669998
# 2023-11-24  189.970001  191.309998 -1.339996 -0.700432 -1.339996
# 2023-11-27  189.789993  189.970001 -0.180008 -0.094756 -0.180008
# 2023-11-28  190.399994  189.789993  0.610001  0.321408  0.610001
# 2023-11-29  189.369995  190.399994 -1.029999 -0.540966 -1.029999
#
# [3501 rows x 5 columns]

# %%
aapl['% Change 2'] = aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2023-11-22  191.309998  190.639999  0.669998  0.351447  0.669998    0.351447
# 2023-11-24  189.970001  191.309998 -1.339996 -0.700432 -1.339996   -0.700432
# 2023-11-27  189.789993  189.970001 -0.180008 -0.094756 -0.180008   -0.094756
# 2023-11-28  190.399994  189.789993  0.610001  0.321408  0.610001    0.321408
# 2023-11-29  189.369995  190.399994 -1.029999 -0.540966 -1.029999   -0.540966
#
# [3501 rows x 6 columns]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2023-11-22  191.309998  190.639999  0.669998  0.351447  0.669998    0.351447
# 2023-11-24  189.970001  191.309998 -1.339996 -0.700432 -1.339996   -0.700432
# 2023-11-27  189.789993  189.970001 -0.180008 -0.094756 -0.180008   -0.094756
# 2023-11-28  190.399994  189.789993  0.610001  0.321408  0.610001    0.321408
# 2023-11-29  189.369995  190.399994 -1.029999 -0.540966 -1.029999   -0.540966
#
# [3501 rows x 6 columns]

# %%
aapl.rename(columns={'% Change 2': '% Change'}, inplace=True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000  0.664833
# ...                ...         ...       ...       ...       ...       ...
# 2023-11-22  191.309998  190.639999  0.669998  0.351447  0.669998  0.351447
# 2023-11-24  189.970001  191.309998 -1.339996 -0.700432 -1.339996 -0.700432
# 2023-11-27  189.789993  189.970001 -0.180008 -0.094756 -0.180008 -0.094756
# 2023-11-28  190.399994  189.789993  0.610001  0.321408  0.610001  0.321408
# 2023-11-29  189.369995  190.399994 -1.029999 -0.540966 -1.029999 -0.540966
#
# [3501 rows x 6 columns]

# %% [markdown]
# ### Resample

# %%
# Getting all of the data at the end of the month
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2023-07-31    196.449997
# 2023-08-31    187.869995
# 2023-09-30    171.210007
# 2023-10-31    170.770004
# 2023-11-30    189.369995
# Freq: M, Name: AAPL, Length: 167, dtype: float64

# %%
# last business day of the month
aapl.AAPL.resample("BM").last()
# Out:
# Date
# 2010-01-29      6.859286
# 2010-02-26      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2023-07-31    196.449997
# 2023-08-31    187.869995
# 2023-09-29    171.210007
# 2023-10-31    170.770004
# 2023-11-30    189.369995
# Freq: BM, Name: AAPL, Length: 167, dtype: float64

# %%
# last business day of the month percent change
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2023-07-31     1.278546
# 2023-08-31    -4.367525
# 2023-09-29    -8.867828
# 2023-10-31    -0.256996
# 2023-11-30    10.891837
# Freq: BM, Name: AAPL, Length: 167, dtype: float64

# %%
del aapl['% Change']
del aapl['lag1']
del aapl['Diff']
del aapl['Diff2']

# %% [markdown]
# ### Mean, std

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-11-22  191.309998
# 2023-11-24  189.970001
# 2023-11-27  189.789993
# 2023-11-28  190.399994
# 2023-11-29  189.369995
#
# [3501 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3500 entries, 2010-01-05 to 2023-11-29
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3500 non-null   float64
# dtypes: float64(1)
# memory usage: 54.7 KB

# %% [markdown]
# ### Histogram

# %%
ret.plot(kind='hist', figsize=(12,8), bins=100)
plt.show()

# %%
# daily mean return
daily_mean_return = ret.mean()
daily_mean_return
# Out:
# AAPL    0.001076
# dtype: float64

# %%
# Variance daily
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000317
# dtype: float64

# %%
# standard deviation daily
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017814
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.017814
# dtype: float64

# %%
# Annual Mean Return
annual_mean_return = daily_mean_return * 252
annual_mean_return
# Out:
# AAPL    0.271225
# dtype: float64

# %%
# Annual Variance return
annual_var_return = var_daily * 252
annual_var_return
# Out:
# AAPL    0.079972
# dtype: float64

# %%
# Annual Standard Deviation Return
annual_std_returns = np.sqrt(annual_var_return)
annual_std_returns
# Out:
# AAPL    0.282794
# dtype: float64

# %%
ret.std() * np.sqrt(252)
# Out:
# AAPL    0.282794
# dtype: float64

# %%
ticker = ["SPY", "KO", "AAPL", "MSFT", "IBM", "DIS"]

# %%
stocks = yf.download(ticker, start="2010-01-01", end="2023-11-30")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks
# Out:
#              Adj Close                                                \
#                   AAPL        DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.478999  27.933924   77.467323  18.498018   23.474918
# 2010-01-05    6.490200  27.864241   76.531494  18.274252   23.482504
# 2010-01-06    6.386964  27.716162   76.034355  18.267773   23.338392
# 2010-01-07    6.375157  27.724874   75.771149  18.222364   23.095680
# 2010-01-08    6.417540  27.768427   76.531494  17.885090   23.254961
# ...                ...        ...         ...        ...         ...
# 2023-11-22  191.309998  95.070000  155.130005  57.958496  377.850006
# 2023-11-24  189.970001  96.059998  155.179993  58.107315  377.429993
# 2023-11-27  189.789993  95.169998  155.570007  57.998184  378.609985
# 2023-11-28  190.399994  92.500000  155.649994  58.117237  382.700012
# 2023-11-29  189.369995  92.500000  156.410004  57.770000  378.850006
#
# ...

# %%
close = stocks.loc[:,"Close"].copy()
close
# Out:
#                   AAPL        DIS         IBM         KO        MSFT  \
# Date
# 2010-01-04    7.643214  32.070000  126.625237  28.520000   30.950001
# 2010-01-05    7.656429  31.990000  125.095604  28.174999   30.959999
# 2010-01-06    7.534643  31.820000  124.282982  28.165001   30.770000
# 2010-01-07    7.520714  31.830000  123.852776  28.094999   30.450001
# 2010-01-08    7.570714  31.879999  125.095604  27.575001   30.660000
# ...                ...        ...         ...        ...         ...
# 2023-11-22  191.309998  95.070000  155.130005  58.419998  377.850006
# 2023-11-24  189.970001  96.059998  155.179993  58.570000  377.429993
# 2023-11-27  189.789993  95.169998  155.570007  58.459999  378.609985
# 2023-11-28  190.399994  92.500000  155.649994  58.580002  382.700012
# 2023-11-29  189.369995  92.500000  156.410004  58.230000  378.850006
#
#                    SPY
# Date
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# 2010-01-07  114.190002
# ...

# %%
normal_close = close.div(close.iloc[0]).mul(100)

# %%
normal_close = close.div(close.iloc[0]).mul(100)
normal_close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  3500.0  0.001076  0.017814 -0.128647 -0.007565  0.000903  0.010481
# DIS   3500.0  0.000438  0.016479 -0.131632 -0.006887  0.000425  0.008208
# IBM   3500.0  0.000159  0.014035 -0.128507 -0.006278  0.000375  0.006993
# KO    3500.0  0.000264  0.010945 -0.096725 -0.004815  0.000468  0.005762
# MSFT  3500.0  0.000850  0.016386 -0.147390 -0.007244  0.000635  0.009257
# SPY   3500.0  0.000457  0.010978 -0.109424 -0.003926  0.000593  0.005777
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary = ret.describe().T.loc[:,["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001076  0.017814
# DIS   0.000438  0.016479
# IBM   0.000159  0.014035
# KO    0.000264  0.010945
# MSFT  0.000850  0.016386
# SPY   0.000457  0.010978

# %%
summary['mean'] = summary['mean'] * 252
summary['std'] = summary['std'] * np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.271225  0.282794
# DIS   0.110467  0.261601
# IBM   0.040162  0.222800
# KO    0.066564  0.173751
# MSFT  0.214225  0.260119
# SPY   0.115279  0.174272

# %%
summary.plot.scatter(x='std', y='mean', figsize=(12, 8), s=50, fontsize=15, c='blue', marker='o')
plt.grid(True)

for i in summary.index:
    plt.annotate(f"{i}\nRisk: {summary.loc[i,'std']:.4f}\nReturn: {summary.loc[i,'mean']:.4f}", 
                 xy=(summary.loc[i,'std']+0.002, summary.loc[i,'mean']+0.002), 
                 size=12, ha='left', va='bottom')

plt.xlabel("Annual Risk (std)", fontsize=15)
plt.ylabel("Annual Return (mean)", fontsize=15)
plt.title("Risk/Return", fontsize=20);

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2023-11-22  0.003514  0.006564  0.007927  0.006721  0.012813  0.003861
# 2023-11-24 -0.007004  0.010413  0.000322  0.002568 -0.001112  0.000615
# 2023-11-27 -0.000948 -0.009265  0.002513 -0.001878  0.003126 -0.001801
# 2023-11-28  0.003214 -0.028055  0.000514  0.002053  0.010803  0.000990
# 2023-11-29 -0.005410  0.000000  0.004883 -0.005975 -0.010060 -0.000703
#
# [3500 rows x 6 columns]

# %%
# Covariance
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000317  0.000123  0.000102  0.000068  0.000173  0.000135
# DIS   0.000123  0.000272  0.000101  0.000079  0.000127  0.000125
# IBM   0.000102  0.000101  0.000197  0.000073  0.000107  0.000100
# KO    0.000068  0.000079  0.000073  0.000120  0.000074  0.000074
# MSFT  0.000173  0.000127  0.000107  0.000074  0.000269  0.000136
# SPY   0.000135  0.000125  0.000100  0.000074  0.000136  0.000121

# %%
# correlations
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.417431  0.407181  0.346703  0.591935  0.690649
# DIS   0.417431  1.000000  0.437550  0.438571  0.471355  0.689786
# IBM   0.407181  0.437550  1.000000  0.477783  0.465472  0.648880
# KO    0.346703  0.438571  0.477783  1.000000  0.410388  0.612685
# MSFT  0.591935  0.471355  0.465472  0.410388  1.000000  0.754173
# SPY   0.690649  0.689786  0.648880  0.612685  0.754173  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap='Reds', annot=True, annot_kws={'size':15}, vmax=0.6)
plt.show()

# %% [markdown]
# ## Challenge 1
# 1. Download 20 random stocks
# 2. Calculate risk and reward potential
# 3. Compare the covariance and correlation
# 4. Find the best 5 to invest in long term based off those metrics

# %%
ticker = ["AMZN", "NVDA", "NFLX", "TSLA", "AAPL", "XOM", "GOOGL", "MSFT", "GE", "SPY",
         "JPM", "JNJ", "PG", "HD", "F", "V", "MA", "COST", "PEP", "ADBE", "FICO"]
stocks = yf.download(ticker, start="2010-01-01", end="2023-11-30")
# Out:
# [*********************100%***********************]  21 of 21 completed

# %%
close = stocks.loc[:,"Close"].copy().dropna()
close
# Out:
#                   AAPL        ADBE        AMZN        COST      F  \
# Date
# 2010-06-29    9.148929   26.900000    5.430500   55.630001   9.88
# 2010-06-30    8.983214   26.430000    5.463000   54.830002  10.08
# 2010-07-01    8.874286   26.660000    5.548000   54.900002  10.57
# 2010-07-02    8.819286   26.730000    5.457000   54.230000  10.28
# 2010-07-06    8.879643   26.340000    5.503000   54.000000  10.16
# ...                ...         ...         ...         ...    ...
# 2023-11-22  191.309998  619.719971  146.710007  589.080017  10.26
# 2023-11-24  189.970001  619.429993  146.740005  591.359985  10.40
# 2023-11-27  189.789993  619.270020  147.729996  594.900024  10.34
# 2023-11-28  190.399994  623.320007  147.029999  594.000000  10.37
# 2023-11-29  189.369995  617.390015  146.320007  587.859985  10.59
#
#                    FICO          GE       GOOGL          HD         JNJ  \
# Date
# 2010-06-29    21.990000   86.951302   11.367868   28.629999   59.240002
# ...

# %%
normal_close = close.div(close.iloc[0]).mul(100)
normal_close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret1 = close.pct_change().dropna()
ret1.head()
# Out:
#                 AAPL      ADBE      AMZN      COST         F      FICO  \
# Date
# 2010-06-30 -0.018113 -0.017472  0.005985 -0.014381  0.020243 -0.009095
# 2010-07-01 -0.012126  0.008702  0.015559  0.001277  0.048611  0.012391
# 2010-07-02 -0.006198  0.002626 -0.016402 -0.012204 -0.027436  0.007706
# 2010-07-06  0.006844 -0.014590  0.008430 -0.004241 -0.011673 -0.011696
# 2010-07-07  0.040381  0.017084  0.030620  0.005370  0.042323  0.044606
#
#                   GE     GOOGL        HD       JNJ       JPM        MA  \
# Date
# 2010-06-30 -0.004144 -0.020495 -0.019560 -0.003038 -0.012142 -0.017045
# 2010-07-01 -0.020804 -0.012271 -0.005344  0.000169 -0.014477  0.015887
# 2010-07-02 -0.016997 -0.006690 -0.005731  0.000169 -0.006929  0.000345
# 2010-07-06  0.006484 -0.001099 -0.015130  0.000000  0.013955 -0.013513
# 2010-07-07  0.046528  0.032403  0.024506  0.025897  0.050096  0.037694
#
#                 MSFT      NFLX      NVDA       PEP        PG       SPY  \
# Date
# ...

# %%
summary1 = ret1.describe().T.loc[:,["mean", "std"]]
summary1
# Out:
#            mean       std
# AAPL   0.001055  0.017730
# ADBE   0.001129  0.019999
# AMZN   0.001191  0.020795
# COST   0.000782  0.012923
# F      0.000247  0.021282
# FICO   0.001381  0.021608
# GE     0.000290  0.019880
# GOOGL  0.000880  0.017185
# HD     0.000816  0.014769
# JNJ    0.000336  0.010692
# JPM    0.000577  0.017605
# MA     0.001042  0.017485
# MSFT   0.000961  0.016428
# NFLX   0.001521  0.032033
# NVDA   0.001941  0.028307
# PEP    0.000357  0.010927
# PG     0.000332  0.010968
# SPY    0.000496  0.010905
# TSLA   0.002133  0.035923
# V      0.000913  0.015923
# XOM    0.000302  0.016168

# %%
summary1['mean'] = summary1['mean'] * 252
summary1['std'] = summary1['std'] * np.sqrt(252)
summary1
# Out:
#            mean       std
# AAPL   0.265781  0.281455
# ADBE   0.284451  0.317478
# AMZN   0.300119  0.330111
# COST   0.197035  0.205140
# F      0.062144  0.337834
# FICO   0.348106  0.343016
# GE     0.073081  0.315581
# GOOGL  0.221714  0.272807
# HD     0.205714  0.234443
# JNJ    0.084778  0.169732
# JPM    0.145424  0.279469
# MA     0.262647  0.277569
# MSFT   0.242077  0.260787
# NFLX   0.383217  0.508515
# NVDA   0.489103  0.449354
# PEP    0.090007  0.173462
# PG     0.083670  0.174119
# SPY    0.124952  0.173104
# TSLA   0.537437  0.570266
# V      0.230050  0.252777
# XOM    0.076226  0.256666

# %%
summary1.plot.scatter(x='std', y='mean', figsize=(25, 12), s=50, fontsize=15, c='blue', marker='o', alpha=0.7)
plt.grid(True)

for i in summary1.index:
    plt.annotate(f"{i}\nRisk: {summary1.loc[i,'std']:.4f}\nReturn: {summary1.loc[i,'mean']:.4f}", 
                 xy=(summary1.loc[i,'std']+0.005, summary1.loc[i,'mean']+0.005), 
                 size=12, ha='left', va='bottom')

plt.xlabel("Annual Risk (std)", fontsize=15)
plt.ylabel("Annual Return (mean)", fontsize=15)
plt.title("Risk/Return", fontsize=20);

# %%
# Covariance
ret1.cov()
# Out:
#            AAPL      ADBE      AMZN      COST         F      FICO        GE  \
# AAPL   0.000314  0.000183  0.000179  0.000098  0.000137  0.000177  0.000120
# ADBE   0.000183  0.000400  0.000222  0.000115  0.000144  0.000233  0.000130
# AMZN   0.000179  0.000222  0.000432  0.000109  0.000135  0.000185  0.000110
# COST   0.000098  0.000115  0.000109  0.000167  0.000090  0.000105  0.000071
# F      0.000137  0.000144  0.000135  0.000090  0.000453  0.000178  0.000213
# FICO   0.000177  0.000233  0.000185  0.000105  0.000178  0.000467  0.000160
# GE     0.000120  0.000130  0.000110  0.000071  0.000213  0.000160  0.000395
# GOOGL  0.000170  0.000198  0.000215  0.000094  0.000136  0.000177  0.000118
# HD     0.000122  0.000146  0.000125  0.000100  0.000148  0.000162  0.000117
# JNJ    0.000065  0.000074  0.000061  0.000058  0.000065  0.000079  0.000071
# JPM    0.000126  0.000141  0.000113  0.000079  0.000212  0.000175  0.000201
# ...

# %%
ret1.corr()
# Out:
#            AAPL      ADBE      AMZN      COST         F      FICO        GE  \
# AAPL   1.000000  0.517240  0.484409  0.429013  0.364063  0.461444  0.339341
# ADBE   0.517240  1.000000  0.533926  0.444329  0.338343  0.538154  0.327431
# AMZN   0.484409  0.533926  1.000000  0.405195  0.304631  0.411203  0.267236
# COST   0.429013  0.444329  0.405195  1.000000  0.327789  0.376391  0.276785
# F      0.364063  0.338343  0.304631  0.327789  1.000000  0.386566  0.503615
# FICO   0.461444  0.538154  0.411203  0.376391  0.386566  1.000000  0.372459
# GE     0.339341  0.327431  0.267236  0.276785  0.503615  0.372459  1.000000
# GOOGL  0.559023  0.574734  0.600921  0.424950  0.370715  0.476377  0.345464
# HD     0.467564  0.492893  0.407195  0.522014  0.471726  0.508363  0.398041
# JNJ    0.344970  0.344175  0.272361  0.419983  0.287058  0.341492  0.334911
# JPM    0.402330  0.399905  0.308820  0.347330  0.566188  0.460186  0.575475
# ...

# %%
plt.figure(figsize=(20,12))
sns.set(font_scale=1)
sns.heatmap(ret1.corr(), cmap='Reds', annot=True, annot_kws={'size':15}, vmax=0.6)
plt.show()

# %%
summary1['net_rating'] = (summary1['mean'] - summary1['std']).sort_values(ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sorting the DataFrame by net_rating in descending order
summary1_sorted = summary1.sort_values(by='net_rating', ascending=False)

# Create a bar plot for net ratings (risk/reward ratio)
plt.figure(figsize=(12, 8))
bars = sns.barplot(x='net_rating', y=summary1_sorted.index, data=summary1_sorted)

# Annotate bars with net ratings
for bar, net_rating in zip(bars.patches, summary1_sorted['net_rating']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{net_rating:.3f}', 
             va='center', fontsize=8, color='black')

plt.title('Net Rating (Risk/Reward Ratio) of Stocks', fontsize=20)
plt.xlabel('Net Rating', fontsize=15)
plt.ylabel('Stock Ticker', fontsize=15)
plt.show()

# %% [markdown]
# From this list of stocks, If I were to have to choose 5 from this list that would give me the best risk to returns I would choose:
# - NVDA, AAPL, MA, FICO, COST because they have the greatest net ratings amongst these stocks

# %% [markdown]
# ## Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95], columns=['Price'])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simple_returns = df.pct_change().dropna()
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
# problem with simple returnns
    # average return is 0.2 then it should be 100*1.2*1.2 when the result is 95
    # mean returns are misleading as crazy

# %%
log_returns = np.log(df/df.shift(1)).dropna()

# %%
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(log_returns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-11-30  456.399994
# 2023-12-01  459.100006
# 2023-12-04  456.690002
# 2023-12-05  456.600006
# 2023-12-06  454.760010
#
# [7770 rows x 1 columns]

# %%
spy.plot(figsize=(10,4), fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %% [markdown]
# ## Rolling Averages (50, 200)

# %%
spy_roll = spy.rolling(window=10)
spy_roll
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
spy_roll = spy_roll.mean()
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-11-30  454.544998
# 2023-12-01  454.769989
# 2023-12-04  454.974991
# 2023-12-05  455.159988
# 2023-12-06  455.159988
#
# [7770 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-11-30  456.399994
# 2023-12-01  459.100006
# 2023-12-04  459.100006
# 2023-12-05  459.100006
# 2023-12-06  459.100006
#
# [7770 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04   45.000000
# ...                ...
# 2023-11-30  456.399994
# 2023-12-01  459.100006
# 2023-12-04  459.100006
# 2023-12-05  459.100006
# 2023-12-06  459.100006
#
# [7770 rows x 1 columns]

# %%
spy["SMA50"] = spy.rolling(window=50, min_periods=5).mean()

# %%
spy
# Out:
#                  Close      SMA50
# Date
# 1993-01-29   43.937500        NaN
# 1993-02-01   44.250000        NaN
# 1993-02-02   44.343750        NaN
# 1993-02-03   44.812500        NaN
# 1993-02-04   45.000000   44.46875
# ...                ...        ...
# 2023-11-30  456.399994  434.33500
# 2023-12-01  459.100006  434.88920
# 2023-12-04  456.690002  435.41460
# 2023-12-05  456.600006  435.90200
# 2023-12-06  454.760010  436.47960
#
# [7770 rows x 2 columns]

# %%
spy.plot(figsize=(11,5), fontsize=10)
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
spy['SMA200'] = spy.Close.rolling(window=200, min_periods=200).mean()

# %%
spy.plot(figsize=(11,5), fontsize=12)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %% [markdown]
# ## Challenge 2
# Take the 5 stocks that you picked and plot the moving averages and graph it

# %%
# NVDA, AAPL, MA, FICO, COST
NVDA = yf.download("NVDA")
AAPL = yf.download("AAPL")
MA = yf.download("MA")
FICO = yf.download("FICO")
COST = yf.download("COST")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
nvda = NVDA.Close.to_frame()
aapl = AAPL.Close.to_frame()
ma = MA.Close.to_frame()
fico = FICO.Close.to_frame()
cost = COST.Close.to_frame()

# %%
# Calculating the 50/200 moving averages for each df
nvda['SMA200'] = nvda.Close.rolling(window=200, min_periods=200).mean()
nvda["SMA50"] = nvda.Close.rolling(window=50, min_periods=5).mean()

aapl['SMA200'] = aapl.Close.rolling(window=200, min_periods=200).mean()
aapl["SMA50"] = aapl.Close.rolling(window=50, min_periods=5).mean()

ma['SMA200'] = ma.Close.rolling(window=200, min_periods=200).mean()
ma["SMA50"] = ma.Close.rolling(window=50, min_periods=5).mean()

fico['SMA200'] = fico.Close.rolling(window=200, min_periods=200).mean()
fico["SMA50"] = fico.Close.rolling(window=50, min_periods=5).mean()

cost['SMA200'] = cost.Close.rolling(window=200, min_periods=200).mean()
cost["SMA50"] = cost.Close.rolling(window=50, min_periods=5).mean()

# %%
nvda
# Out:
#                  Close      SMA200       SMA50
# Date
# 1999-01-22    0.410156         NaN         NaN
# 1999-01-25    0.453125         NaN         NaN
# 1999-01-26    0.417969         NaN         NaN
# 1999-01-27    0.416667         NaN         NaN
# 1999-01-28    0.415365         NaN    0.422656
# ...                ...         ...         ...
# 2023-11-30  467.700012  380.892951  450.790201
# 2023-12-01  467.649994  382.093000  451.939801
# 2023-12-04  455.100006  383.268400  452.719801
# 2023-12-05  465.660004  384.527300  453.588601
# 2023-12-06  455.029999  385.769700  454.307001
#
# [6260 rows x 3 columns]

# %% [markdown]
# ### Custom Function

# %%
def plot_moving_averages(df, stock_name, figsize=(20, 10), title='Stock Price and Moving Averages'):
    """
    Plots stock price, 50-day moving average, and 200-day moving average.

    Parameters:
    - df: DataFrame containing columns 'Close', 'SMA50', and 'SMA200'.
    - stock_name: String, the name of the stock.
    - figsize: Tuple, optional, default is (20, 10). Size of the figure.
    - title: String, optional, default is 'Stock Price and Moving Averages'. Title of the plot.

    Returns:
    None
    """
    # Set Seaborn style
    sns.set(style="whitegrid")

    # Plotting stock price, 50-day, and 200-day moving averages with improved styling
    plt.figure(figsize=figsize)

    # Plotting stock price
    plt.plot(df.index, df['Close'], label='Stock Price', color='b', linewidth=2)

    # Plotting 50-day moving average
    plt.plot(df.index, df['SMA50'], label='50-day MA', color='g', linestyle='--', linewidth=2)

    # Plotting 200-day moving average
    plt.plot(df.index, df['SMA200'], label='200-day MA', color='r', linestyle='-.', linewidth=2)

    # Adding title with stock name and labels
    plt.title(f"{stock_name} {title}", fontsize=18)
    plt.xlabel('Date', fontsize=14)
    plt.ylabel('Price', fontsize=14)

    # Adding a grid for better readability
    plt.grid(True, linestyle='--', alpha=0.7)

    # Adding legend with larger font size
    plt.legend(loc='upper left', fontsize=14)

    # Show the plot
    plt.show()

# %% [markdown]
# ### Graphing 5 stocks

# %%
plot_moving_averages(nvda, 'NVDIA')
plot_moving_averages(fico, 'FICO')
plot_moving_averages(cost, 'Costco')
plot_moving_averages(aapl, 'Apple')
plot_moving_averages(ma, 'MasterCard')

# %% [markdown]
# ### EMA

# %%
spy['EMA100'] = spy.Close.ewm(span=100, min_periods=100).mean()

# %%
spy
# Out:
#                  Close      SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500        NaN         NaN         NaN
# 1993-02-01   44.250000        NaN         NaN         NaN
# 1993-02-02   44.343750        NaN         NaN         NaN
# 1993-02-03   44.812500        NaN         NaN         NaN
# 1993-02-04   45.000000   44.46875         NaN         NaN
# ...                ...        ...         ...         ...
# 2023-11-30  456.399994  434.33500  427.412951  436.694687
# 2023-12-01  459.100006  434.88920  427.638551  437.138356
# 2023-12-04  456.690002  435.41460  427.880601  437.525518
# 2023-12-05  456.600006  435.90200  428.127301  437.903230
# 2023-12-06  454.760010  436.47960  428.405651  438.237028
#
# [7770 rows x 4 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %%
spy['Day'] = spy.index.day_name()

# %%
spy['Quarter'] = spy.index.quarter

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame().copy()

# %%
all_days = pd.date_range(start='2010-12-31', end='2023-12-1', freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2023-11-22', '2023-11-23', '2023-11-24', '2023-11-25',
#                '2023-11-26', '2023-11-27', '2023-11-28', '2023-11-29',
#                '2023-11-30', '2023-12-01'],
#               dtype='datetime64[ns]', length=4719, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-11-30  456.399994
# 2023-12-01  459.100006
# 2023-12-04  456.690002
# 2023-12-05  456.600006
# 2023-12-06  454.760010
#
# [7770 rows x 1 columns]

# %%
spy = spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-11-27  454.480011
# 2023-11-28  454.929993
# 2023-11-29  454.609985
# 2023-11-30  456.399994
# 2023-12-01  459.100006
#
# [4719 rows x 1 columns]

# %%
# Forward fill
spy.fillna(method="ffill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-11-27  454.480011
# 2023-11-28  454.929993
# 2023-11-29  454.609985
# 2023-11-30  456.399994
# 2023-12-01  459.100006
#
# [4719 rows x 1 columns]

# %%
# Backward fill
spy.fillna(method="bfill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-11-27  454.480011
# 2023-11-28  454.929993
# 2023-11-29  454.609985
# 2023-11-30  456.399994
# 2023-12-01  459.100006
#
# [4719 rows x 1 columns]

# %% [markdown]
# ## Cumulative Returns, Drawdowns, etc.

# %%
apple = yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple['d_returns'] = np.log(apple.div(apple.shift(1)))

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-11-30  189.949997   0.003058
# 2023-12-01  191.240005   0.006768
# 2023-12-04  189.429993  -0.009510
# 2023-12-05  193.419998   0.020844
# 2023-12-06  192.320007  -0.005703
#
# [10836 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.312170698950106

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1498.4262938845277

# %%
apple['cumm_returns'] = apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns
# Date
# 1980-12-15    0.121652  -0.053581      0.947829
# 1980-12-16    0.112723  -0.076231      0.878261
# 1980-12-17    0.115513   0.024450      0.899998
# 1980-12-18    0.118862   0.028580      0.926092
# 1980-12-19    0.126116   0.059239      0.982610
# ...                ...        ...           ...
# 2023-11-30  189.949997   0.003058   1479.960790
# 2023-12-01  191.240005   0.006768   1490.011656
# 2023-12-04  189.429993  -0.009510   1475.909271
# 2023-12-05  193.419998   0.020844   1506.996672
# 2023-12-06  192.320007  -0.005703   1498.426294
#
# [10836 rows x 3 columns]

# %%
apple.cumm_returns.plot(figsize=(12,8), title='Apple Buy and Hold', fontsize=12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.1700504813709327

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.451876024830094

# %%
# Calculating draw downs (finding the peaks and valleys)
apple['cumm_max'] = apple.cumm_returns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns     cumm_max
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829
# 1980-12-17    0.115513   0.024450      0.899998     0.947829
# 1980-12-18    0.118862   0.028580      0.926092     0.947829
# 1980-12-19    0.126116   0.059239      0.982610     0.982610
# ...                ...        ...           ...          ...
# 2023-11-30  189.949997   0.003058   1479.960790  1530.604356
# 2023-12-01  191.240005   0.006768   1490.011656  1530.604356
# 2023-12-04  189.429993  -0.009510   1475.909271  1530.604356
# 2023-12-05  193.419998   0.020844   1506.996672  1530.604356
# 2023-12-06  192.320007  -0.005703   1498.426294  1530.604356
#
# [10836 rows x 4 columns]

# %%
apple[["cumm_returns","cumm_max"]].plot(figsize=(15,8), title='Apple Cumulative Max', fontsize=12)
plt.show()

# %%
apple['draw_down'] = apple["cumm_max"] - apple["cumm_returns"]

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns     cumm_max  draw_down
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610   0.000000
# ...                ...        ...           ...          ...        ...
# 2023-11-30  189.949997   0.003058   1479.960790  1530.604356  50.643566
# 2023-12-01  191.240005   0.006768   1490.011656  1530.604356  40.592699
# 2023-12-04  189.429993  -0.009510   1475.909271  1530.604356  54.695084
# 2023-12-05  193.419998   0.020844   1506.996672  1530.604356  23.607683
# 2023-12-06  192.320007  -0.005703   1498.426294  1530.604356  32.178062
#
# [10836 rows x 5 columns]

# %%
apple.draw_down.max()
# Out:
# 444.02718404402026

# %%
apple.draw_down.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cumm_returns     cumm_max   draw_down
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-12-29  129.610001   0.027931   1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466   1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122    974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261    984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661    974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
# Calculating percentage drawdown
apple['draw_down_percentage'] = (apple['cumm_max'] - apple['cumm_returns']) / apple['cumm_max']

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns     cumm_max  draw_down  \
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610   0.000000
# ...                ...        ...           ...          ...        ...
# 2023-11-30  189.949997   0.003058   1479.960790  1530.604356  50.643566
# 2023-12-01  191.240005   0.006768   1490.011656  1530.604356  40.592699
# 2023-12-04  189.429993  -0.009510   1475.909271  1530.604356  54.695084
# 2023-12-05  193.419998   0.020844   1506.996672  1530.604356  23.607683
# 2023-12-06  192.320007  -0.005703   1498.426294  1530.604356  32.178062
#
#             draw_down_percentage
# Date
# 1980-12-15              0.000000
# ...

# %%
apple.draw_down_percentage.max()
# Out:
# 0.82216567924191

# %%
apple.draw_down_percentage.idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cumm_returns  cumm_max  draw_down  \
# Date
# 1980-12-15  0.121652  -0.053581      0.947829  0.947829   0.000000
# 1980-12-16  0.112723  -0.076231      0.878261  0.947829   0.069569
# 1980-12-17  0.115513   0.024450      0.899998  0.947829   0.047831
# 1980-12-18  0.118862   0.028580      0.926092  0.947829   0.021738
# 1980-12-19  0.126116   0.059239      0.982610  0.982610   0.000000
# ...              ...        ...           ...       ...        ...
# 1997-12-17  0.124442  -0.026549      0.969567  5.060882   4.091315
# 1997-12-18  0.123326  -0.009008      0.960872  5.060882   4.100010
# 1997-12-19  0.122210  -0.009090      0.952177  5.060882   4.108705
# 1997-12-22  0.118862  -0.027778      0.926092  5.060882   4.134790
# 1997-12-23  0.115513  -0.028580      0.899998  5.060882   4.160883
#
#             draw_down_percentage
# Date
# 1980-12-15              0.000000
# 1980-12-16              0.073398
# 1980-12-17              0.050464
# ...

# %% [markdown]
# ## SMA Strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-11-30  189.949997
# 2023-12-01  191.240005
# 2023-12-04  189.429993
# 2023-12-05  193.419998
# 2023-12-06  192.320007
#
# [8296 rows x 1 columns]

# %%
# moving averages
sma_s = 50
sma_l = 100

data['sma_s'] = data.Close.rolling(sma_s).mean()
data['sma_l'] = data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2023-11-30  189.949997  179.105400  181.564201
# 2023-12-01  191.240005  179.451601  181.578901
# 2023-12-04  189.429993  179.744401  181.567801
# 2023-12-05  193.419998  180.091201  181.595101
# 2023-12-06  192.320007  180.498401  181.578401
#
# [8296 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title='Apple - SMA {} | SMA {}'.format(sma_s, sma_l), fontsize=12);

# %%
data.loc['2021'].plot(figsize=(12,8), title='Apple - SMA {} | SMA {}'.format(sma_s, sma_l), fontsize=12);

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-11-30  189.949997  179.105400  181.564201
# 2023-12-01  191.240005  179.451601  181.578901
# 2023-12-04  189.429993  179.744401  181.567801
# 2023-12-05  193.419998  180.091201  181.595101
# 2023-12-06  192.320007  180.498401  181.578401
#
# [8197 rows x 3 columns]

# %%
data['position'] = np.where(data['sma_s']>data['sma_l'], 1, -1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-11-30  189.949997  179.105400  181.564201        -1
# 2023-12-01  191.240005  179.451601  181.578901        -1
# 2023-12-04  189.429993  179.744401  181.567801        -1
# 2023-12-05  193.419998  180.091201  181.595101        -1
# 2023-12-06  192.320007  180.498401  181.578401        -1
#
# [8197 rows x 4 columns]

# %%
data.loc['2018':'2023',["sma_s", "sma_l",'position']].plot(figsize=(12,8), title='Apple - SMA {} | SMA {}'.format(sma_s, sma_l), fontsize=12,
                                              secondary_y='position');

# %%
# buy and hold column
data['returns_bnh'] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returns_bnh
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1          NaN
# 1991-05-24    0.409598    0.530960    0.513538         1     0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1     0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1     0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1     0.013209
# ...                ...         ...         ...       ...          ...
# 2023-11-30  189.949997  179.105400  181.564201        -1     0.003058
# 2023-12-01  191.240005  179.451601  181.578901        -1     0.006768
# 2023-12-04  189.429993  179.744401  181.567801        -1    -0.009510
# 2023-12-05  193.419998  180.091201  181.595101        -1     0.020844
# 2023-12-06  192.320007  180.498401  181.578401        -1    -0.005703
#
# [8197 rows x 5 columns]

# %%
# strategy column
data['strategy'] = data['returns_bnh'] * data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returns_bnh  \
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1          NaN
# 1991-05-24    0.409598    0.530960    0.513538         1     0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1     0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1     0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1     0.013209
# ...                ...         ...         ...       ...          ...
# 2023-11-30  189.949997  179.105400  181.564201        -1     0.003058
# 2023-12-01  191.240005  179.451601  181.578901        -1     0.006768
# 2023-12-04  189.429993  179.744401  181.567801        -1    -0.009510
# 2023-12-05  193.419998  180.091201  181.595101        -1     0.020844
# 2023-12-06  192.320007  180.498401  181.578401        -1    -0.005703
#
#             strategy
# Date
# 1991-05-23       NaN
# 1991-05-24  0.016483
# 1991-05-28  0.002721
# 1991-05-29  0.021507
# ...

# %%
data.dropna(inplace=True)

# %%
data[['returns_bnh','strategy']].sum()
# Out:
# returns_bnh    6.168223
# strategy       1.967840
# dtype: float64

# %%
data[['returns_bnh','strategy']].sum().apply(np.exp)
# Out:
# returns_bnh    477.336930
# strategy         7.155204
# dtype: float64

# %%
data[['returns_bnh','strategy']].std()*np.sqrt(252) # annual std
# Out:
# returns_bnh    0.435320
# strategy       0.435467
# dtype: float64

# %%
data.Close.plot(figsize=(12,8));

# %% [markdown]
# ### Charge Point Stock

# %%
CHPT = yf.download("CHPT")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
chpt = CHPT.Close.copy().to_frame() # convert data to DataFrame
close = CHPT.loc[:,"Close"].copy().dropna()
close
# Out:
# Date
# 2019-09-16    9.76
# 2019-09-17    9.76
# 2019-09-18    9.72
# 2019-09-19    9.72
# 2019-09-20    9.85
#               ...
# 2023-11-30    1.86
# 2023-12-01    2.02
# 2023-12-04    2.09
# 2023-12-05    1.99
# 2023-12-06    2.05
# Name: Close, Length: 1065, dtype: float64

# %%
normal_close = close.div(close.iloc[0]).mul(100)
normal_close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data['position2'] = np.where(data['sma_s']>data['sma_l'], 1, 0)

# %%
data['strategy2'] = data['returns_bnh'] * data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[['returns_bnh','strategy2']].sum()
# Out:
# returns_bnh    6.151740
# strategy2      4.051548
# dtype: float64

# %%
data[['returns_bnh','strategy2']].sum().apply(np.exp)
# Out:
# returns_bnh    469.533569
# strategy2       57.486403
# dtype: float64

# %%
data[['returns_bnh','strategy2']].std()*np.sqrt(252) # risk
# Out:
# returns_bnh    0.435338
# strategy2      0.336511
# dtype: float64

# %%
data[['strategy','strategy2']].std()*np.sqrt(252) # risk
# Out:
# strategy     0.435484
# strategy2    0.336511
# dtype: float64

# %% [markdown]
# Strategy 2 is greater than strategy 1

# %% [markdown]
# ## Challenge 3
# 1. Create a Bias strategy
# 2. Compare draw downs
# 3. Pick the best 3 stocks for your portfolio

# %% [markdown]
# # Stock Prediction

# %% [markdown]
# ### Creating training/test data

# %% [markdown]
# ## Imports

# %%
train_data.head()
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003

# %%
test_data.tail()
# Out:
#                  Close
# 2023-11-27  454.480011
# 2023-11-28  454.929993
# 2023-11-29  454.609985
# 2023-11-30  456.399994
# 2023-12-01  459.100006

# %%
features = ['Open', 'Volume']
target = 'Close'

# Create and train model
model = xgb.XGBRegressor()
model.fit(train_data[features], train_data[target])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [191], line 6
#       4 # Create and train model
#       5 model = xgb.XGBRegressor()
# ----> 6 model.fit(train_data[features], train_data[target])
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
# Make and show the predictions on the test data
predictions = model.predict(test_data[features])
print('Model Predictions:')
print(predictions)

# %%
spy_test.to_csv("test.csv")

# %%
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
# Out:
# C:\Users\cjhun\anaconda3\envs\dojo-env\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
spy.index = pd.to_datetime(spy.index)

# Split the data into training and testing sets
train_data = spy.iloc[:int(0.8 * len(spy)), :]
test_data = spy.iloc[int(0.8 * len(spy)):, :]

# %%
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-11-27  454.480011
# 2023-11-28  454.929993
# 2023-11-29  454.609985
# 2023-11-30  456.399994
# 2023-12-01  459.100006
#
# [4719 rows x 1 columns]

# %%
spy.head()
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003

# %%
# Show the models accuracies
accuracy = model.score(test_data[features], test_data[target])
print(accuracy)
